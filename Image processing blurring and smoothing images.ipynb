# %% [raw]
# Gamma correction
# Image kernel
# gamma  ==> gamma less image appears to be brighter(fad out)
# kernel
# filter2D
# blur
# guassian blur
# median blur

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('addnoiseimage.png')

# %%
#plt.imshow(img)
fig = plt.figure(figsize=(10,10))
ax =fig.add_subplot(111)
ax.imshow(img)

# %%
Mblur = cv2.medianBlur(img,5)

# %%
fig = plt.figure(figsize=(10,10))
ax =fig.add_subplot(111)
ax.imshow(Mblur)
