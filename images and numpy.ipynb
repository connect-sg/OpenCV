# %% [raw]
# PIL
# change to array
# shape
# get image in  R G B
# cmap
# get rid of single color channel

# %%
from PIL import Image # Python Imaging Library
import numpy as np
import matplotlib.pyplot as plt

# %%
image = Image.open('sample_img.jpeg')

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1867x1400 at 0x7FC1A634D0D0>

# %%
type(image)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
np_image = np.asarray(image)

# %%
type(np_image)
# Out:
# numpy.ndarray

# %%
plt.imshow(np_image)

# %%
np_image
# Out:
# array([[[255, 132,  12],
#         [255, 131,  13],
#         [255, 129,  16],
#         ...,
#         [192,  58,  69],
#         [193,  57,  67],
#         [194,  59,  66]],
#
#        [[255, 131,  13],
#         [255, 130,  14],
#         [253, 127,  16],
#         ...,
#         [191,  57,  68],
#         [193,  57,  67],
#         [193,  58,  65]],
#
#        [[254, 128,  15],
#         [253, 127,  16],
#         [252, 126,  16],
#         ...,
#         [191,  57,  68],
#         [191,  57,  66],
#         [193,  58,  65]],
#
#        ...,
#
#        [[253, 140,   0],
#         [253, 140,   0],
#         [253, 140,   0],
#         ...,
#         [ 96,  59,  41],
#         [ 96,  59,  41],
#         [ 97,  60,  42]],
#
#        [[253, 140,   0],
#         [253, 140,   0],
#         [253, 140,   0],
#         ...,
#         [ 95,  58,  40],
#         [ 95,  58,  40],
#         [ 96,  59,  41]],
#
#        [[253, 140,   0],
#         [253, 140,   0],
#         [253, 140,   0],
# ...

# %%
#SHAPE
np_image.shape
# Out:
# (1400, 1867, 3)

# %%
#R 0 G 1 B 2
plt.imshow(np_image[:,:,0],cmap = 'gray')

# %%
plt.imshow(np_image[:,:,1],cmap='gray')

# %%
plt.imshow(np_image[:,:,2],cmap='gray')

# %%
plt.imshow(np_image[:,:,0])

# %%
plt.imshow(np_image[:,:,1])

# %%
plt.imshow(np_image[:,:,2])

# %%
np_image[:,:,0].shape
# Out:
# (1400, 1867)

# %%
#get rid of green color
red_image = np_image[:,:,0]

# %%
plt.imshow(red_image)
